# %%
import json 
# %load_ext autoreload
# %autoreload 2

with open("results.json", "r") as file: 
  data = json.load(file)

# %%
epoch_num = 15 # epoch number to analyze 
epoch_data = [] 
rank_metrics = [] 
keep_metrics = [] 
general_metrics = [] 

for data_idx, data in enumerate(data): 
  if data["epoch"] == 15: 
    epoch_data.append(data)

for data in epoch_data: 
  print(data["all_metrics"] + "\n")
for data in epoch_data: 
  print(data["rank_metrics"])
# Out:
# [{'timestamp': '2025-11-27T13:48:54.129914', 'epoch': 15, 'metrics': {'avg_loss': 0.9439578837280589, 'avg_f1_score': 0.5958548641363351, 'avg_accuracy': 0.3402240538025545, 'avg_precision': 0.5961534654250354, 'avg_recall': 0.595681989706035, 'avg_specificity': 0.6685327363191579}, 'thread_metrics': {'percentage_kept_long_threads': 0.01951494641849972, 'percentage_kept_lone_threads': 0.10817822899041173, 'percentage_total_long_threads': 0.026959954878736606, 'percentage_total_lone_threads': 0.4285391990975747}, 'model_config': {'architecture': 'CDModel (Multi-head + Self-Attention)', 'input_dim': 768, 'attention': {'num_heads': 4, 'embed_dim': 768}, 'hidden_dim1': 256, 'hidden_dim2': 128, 'hidden_dim3': 64, 'output_heads': {'thread_prediction': 1, 'keep_discard_prediction': 1}, 'dropout_rate': 0.2, 'activation': 'ReLU', 'total_parameters': 2600449, 'trainable_parameters': 2600449}, 'training_config': {'learning_rate': 0.001, 'optimizer': 'Adam', 'loss_function': 'ListNetLoss', 'max_messages_per_example': 17, 'num_examples': 2295, 'batch_size': 5, 'f1_threshold': 0.5, 'using_attention': 'TRUE'}}, {'timestamp': '2025-11-27T20:16:11.261140', 'epoch': 15, 'metrics': {'avg_loss': 0.9239013921935932, 'avg_f1_score': 0.5935254393887488, 'avg_accuracy': 0.34095295192417496, 'avg_precision': 0.5938291963831532, 'avg_recall': 0.5933495800761988, 'avg_specificity': 0.6807554236331215}, 'thread_metrics': {'percentage_kept_long_threads': 0.007219402143260011, 'percentage_kept_lone_threads': 0.10513254371122391, 'percentage_total_long_threads': 0.027298364354201916, 'percentage_total_lone_threads': 0.42233502538071066}, 'model_config': {'architecture': 'CDModel (Multi-head + Self-Attention)', 'input_dim': 768, 'attention': {'num_heads': 4, 'embed_dim': 768}, 'hidden_dim1': 256, 'hidden_dim2': 128, 'hidden_dim3': 64, 'output_heads': {'thread_prediction': 1, 'keep_discard_prediction': 1}, 'dropout_rate': 0.2, 'activation': 'ReLU', 'total_parameters': 2600449, 'trainable_parameters': 2600449}, 'training_config': {'learning_rate': 0.001, 'optimizer': 'Adam', 'loss_function': 'ListNetLoss', 'max_messages_per_example': 17, 'num_examples': 2295, 'batch_size': 5, 'f1_threshold': 0.5, 'using_attention': 'TRUE'}}, {'timestamp': '2025-12-01T00:16:43.115831', 'epoch': 15, 'all_metrics': {'avg_loss': 1.6406067736264371, 'avg_f1_score': 0.39427069296004486, 'avg_accuracy': 0.2940845919982084, 'avg_precision': 0.4040677508192149, 'avg_recall': 0.4161548553935084, 'avg_specificity': 0.7154246518082535}, 'rank_head_metrics': {'avg_loss': 1.6406067736264371, 'avg_f1_score': 0.5394303313410195, 'avg_accuracy': 0.29511085546956706, 'avg_precision': 0.5397394252079464, 'avg_recall': 0.539251382260167, 'avg_specificity': 0.6582502620203938}, 'keep_head_metrics': {'avg_loss': 1.6406067736264371, 'avg_f1_score': 0.2491110545790703, 'avg_accuracy': 0.29305832852684977, 'avg_precision': 0.26839607643048347, 'avg_recall': 0.29305832852684977, 'avg_specificity': 0.7725990415961134}, 'thread_metrics': {'percentage_kept_long_threads': 0.0, 'percentage_kept_lone_threads': 0.11178793006204174, 'percentage_total_long_threads': 0.02825719120135364, 'percentage_total_lone_threads': 0.42351945854483924}, 'model_config': {'architecture': 'CDModel (Multi-head + Self-Attention)', 'input_dim': 768, 'attention': {'num_heads': 4, 'embed_dim': 768}, 'hidden_dim1': 256, 'hidden_dim2': 128, 'hidden_dim3': 64, 'output_heads': {'thread_prediction': 1, 'keep_discard_prediction': 1}, 'dropout_rate': 0.2, 'activation': 'ReLU', 'total_parameters': 2600514, 'trainable_parameters': 2600514}, 'training_config': {'learning_rate': 0.001, 'optimizer': 'Adam', 'rank_loss_function': 'ListNetLoss', 'keep_loss_function': 'BCELoss', 'max_messages_per_example': 17, 'num_examples': 2295, 'batch_size': 5, 'f1_threshold': 0.5, 'using_attention': 'TRUE'}}, {'timestamp': '2025-12-01T01:55:40.881382', 'epoch': 15, 'all_metrics': {'avg_loss': 1.3207637466129214, 'avg_f1_score': 0.5333802178191235, 'avg_accur ...
